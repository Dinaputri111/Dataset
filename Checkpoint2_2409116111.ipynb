# %% [markdown]
# <a href="https://colab.research.google.com/github/Dinaputri111/Dataset/blob/main/Checkpoint2_2409116111.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Analisis Indeks Pencemaran Udara di Provinsi DKI Jakarta Tahun 2021**

# %% [markdown]
# # Business Understanding

# %% [markdown]
# ## 1. Business Objective
# Menganalisis pola perubahan kualitas udara di Stasiun DKI Jakarta tahun 2021 untuk mengetahui tingkat pencemaran udara tertinggi dan terendah dari waktu ke waktu dan menentukan wilayah dengan tingkat pencemaran tertinggi sehingga dapat memprediksi kualitas udara di masa depan untuk membantu perencanaan kebijakan lingkungan yang lebih efektif.
# ## 2. Assess Situation
#  aktivitas Transportasi, industri, dan domestik saat ini memiliki dampak signifikan bagi penurunan kualitas udara. Tingginya konsentrasi polutan seperti PM₂.₅ dan PM₁₀ telah melampaui ambang batas yang direkomendasikan oleh Organisasi Kesehatan Dunia (WHO), yang dapat berdampak negatif pada kesehatan masyarakat. Menganalisis Data kualitas udara yang diukur dari 5 stasiun pemantau kualitas udara (SPKU) membantu dalam mengidentifikasi tingkat pencemaran udara di beberapa wilayah DKI Jakarta dan dapat menjadi perencanaan strategis dalam mitigasi polusi.
#
# ## 3. Data Mining Goals
# Data Mining Goals dalam analisis ini adalah memahami pola standar kualitas udara harian di beberapa stasiun DKI Jakarta dengan menghitung rata-rata, median, nama stasiun yang paling banyak muncul di dataset, stasiun dengan pencemaran paling tinggi, dan korelasi antara berbagai polutan hingga visualisasi datanya.

# %% [markdown]
# ## Project Plan

# %% [markdown]
# Untuk menganalisis dataset, langkah awal adalah menampilkan data yang telah tersedia. Kemudian dilakukan analisis pola pencemaran udara di Stasiun. Berikut terdapat beberapa tujuan utama yang ingin dicapai:

# %% [markdown]
# # Tampilan Data

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv("/content/drive/MyDrive/Fiks bgt.csv")

df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#         tanggal                           stasiun  pm10  pm25   so2    co  \
# 0    2021-01-01               DKI4 (Lubang Buaya)  41.0   NaN  37.0  14.0
# 1    2021-01-01                DKI1 (Bunderan HI)  38.0  53.0  29.0   6.0
# 2    2021-01-02                DKI1 (Bunderan HI)  27.0  46.0  27.0   7.0
# 3    2021-01-03                DKI1 (Bunderan HI)  44.0  58.0  25.0   7.0
# 4    2021-01-04                DKI1 (Bunderan HI)  30.0  48.0  24.0   4.0
# ..          ...                               ...   ...   ...   ...   ...
# 770  2021-12-08  DKI5 (Kebon Jeruk) Jakarta Barat  44.0  66.0  17.0  13.0
# 771  2021-12-09  DKI5 (Kebon Jeruk) Jakarta Barat  30.0  50.0  20.0   5.0
# 772  2021-12-13  DKI5 (Kebon Jeruk) Jakarta Barat  22.0  45.0  20.0   3.0
# 773  2021-12-30  DKI5 (Kebon Jeruk) Jakarta Barat  53.0  75.0  25.0  15.0
# 774  2021-12-31  DKI5 (Kebon Jeruk) Jakarta Barat  60.0  87.0  28.0  19.0
#
#        o3   no2 max critical categori
# 0    35.0   4.0  41     PM10     BAIK
# 1    31.0  13.0  53     PM25   SEDANG
# 2    47.0   7.0  47       O3     BAIK
# 3    40.0  13.0  58     PM25   SEDANG
# 4    32.0   7.0  48     PM25     BAIK
# ..    ...   ...  ..      ...      ...
# 770  23.0  30.0  66     PM25   SEDANG
# 771  31.0  15.0  50     PM25     BAIK
# 772  16.0  14.0  45     PM25     BAIK
# 773  23.0  44.0  75     PM25   SEDANG
# 774  30.0  53.0  87     PM25   SEDANG
#
# [775 rows x 11 columns]

# %% [markdown]
# # Tampilan 5 Baris pertama

# %%
df.head()
# Out:
#       tanggal              stasiun  pm10  pm25   so2    co    o3   no2 max  \
# 0  2021-01-01  DKI4 (Lubang Buaya)  41.0   NaN  37.0  14.0  35.0   4.0  41
# 1  2021-01-01   DKI1 (Bunderan HI)  38.0  53.0  29.0   6.0  31.0  13.0  53
# 2  2021-01-02   DKI1 (Bunderan HI)  27.0  46.0  27.0   7.0  47.0   7.0  47
# 3  2021-01-03   DKI1 (Bunderan HI)  44.0  58.0  25.0   7.0  40.0  13.0  58
# 4  2021-01-04   DKI1 (Bunderan HI)  30.0  48.0  24.0   4.0  32.0   7.0  48
#
#   critical categori
# 0     PM10     BAIK
# 1     PM25   SEDANG
# 2       O3     BAIK
# 3     PM25   SEDANG
# 4     PM25     BAIK

# %% [markdown]
# Info Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   775 non-null    object
#  1   stasiun   775 non-null    object
#  2   pm10      743 non-null    float64
#  3   pm25      732 non-null    float64
#  4   so2       753 non-null    float64
#  5   co        762 non-null    float64
#  6   o3        739 non-null    float64
#  7   no2       760 non-null    float64
#  8   max       775 non-null    object
#  9   critical  775 non-null    object
#  10  categori  774 non-null    object
# dtypes: float64(6), object(5)
# memory usage: 66.7+ KB

# %% [markdown]
# # Menghitung Rata-rata Standar Kualitas Udara

# %%
df.mean(numeric_only=True)
# Out:
# pm10    52.981157
# pm25    82.870219
# so2     35.442231
# co      11.599738
# o3      30.016238
# no2     19.213158
# dtype: float64

# %% [markdown]
# # Menghitung Jumlah Nama Stasiun yang Paling Banyak Muncul dalam Dataset

# %%
kolom_tertentu = "stasiun"
if kolom_tertentu in df.columns:
    print(df[kolom_tertentu].value_counts())
else:
    print(f"\nKolom '{kolom_tertentu}' tidak ditemukan dalam dataset.")
# Out:
# stasiun
# DKI4 (Lubang Buaya)                 230
# DKI5 (Kebon Jeruk) Jakarta Barat    174
# DKI2 (Kelapa Gading)                130
# DKI1 (Bunderan HI)                  124
# DKI3 (Jagakarsa)                    117
# Name: count, dtype: int64

# %% [markdown]
# # Menghitung Median untuk mengetahui nilai tengah tingkat kualitas udara

# %%
df.median(numeric_only=True)
# Out:
# pm10    56.0
# pm25    86.0
# so2     37.0
# co      11.0
# o3      28.0
# no2     18.0
# dtype: float64

# %% [markdown]
# # Menghitung Korelasi antara berbagai polutan udara (PM₁₀, PM₂.₅, SO₂, CO, O₃, dan NO₂).
# Partikulat kasar(PM10) dan partikulat halus (PM2.5) memiliki korelasi tinggi dan cenderung naik dan turun bersama, hal ini karena sumbernya sering kali sama seperti dari asap kendaraan, industri atau debu.

# %%
df.corr(numeric_only=True)
# Out:
#           pm10      pm25       so2        co        o3       no2
# pm10  1.000000  0.853117  0.498182  0.408741  0.307034  0.500113
# pm25  0.853117  1.000000  0.400782  0.375076  0.238479  0.483414
# so2   0.498182  0.400782  1.000000 -0.001521  0.365545  0.097520
# co    0.408741  0.375076 -0.001521  1.000000  0.038629  0.514404
# o3    0.307034  0.238479  0.365545  0.038629  1.000000  0.002475
# no2   0.500113  0.483414  0.097520  0.514404  0.002475  1.000000

# %% [markdown]
# # Menentukan Stasiun dengan Pencemaran Tertinggi

# %%
df.groupby("stasiun")[["pm25", "pm10", "co", "no2", "o3", "so2"]].mean().sort_values(by="pm25", ascending=False).head(5)
# Out:
#                                        pm25       pm10         co        no2  \
# stasiun
# DKI4 (Lubang Buaya)               99.298246  57.909953  12.135135  19.475771
# DKI5 (Kebon Jeruk) Jakarta Barat  81.589041  48.323171  11.287356  21.463855
# DKI2 (Kelapa Gading)              81.441667  57.562500  11.032000  19.905512
# DKI3 (Jagakarsa)                  79.842105  57.551724  10.538462  15.482759
# DKI1 (Bunderan HI)                58.338710  41.750000  12.653226  18.500000
#
#                                          o3        so2
# stasiun
# DKI4 (Lubang Buaya)               27.506849  39.629956
# DKI5 (Kebon Jeruk) Jakarta Barat  24.856322  26.157233
# DKI2 (Kelapa Gading)              49.179688  45.685039
# DKI3 (Jagakarsa)                  32.659574  38.594828
# DKI1 (Bunderan HI)                19.903226  26.241935

# %% [markdown]
# # Visualisasi Data pada Stasiun dengan Pencemaran Tertinggi (PM2.5)

# %%
import matplotlib.pyplot as plt

df.groupby("stasiun")["pm25"].mean().sort_values(ascending=False).plot(kind='bar', color='red', figsize=(10,5))
plt.title("Rata-rata PM2.5 per Stasiun")
plt.xlabel("Stasiun")
plt.ylabel("PM2.5")
plt.show()

# %% [markdown]
# # DATA UNDERSTANDING

# %% [markdown]
# ## Sumber Data

# %% [markdown]
# Dataset yang digunakan dalam analisis ini adalah "Indeks Standar Pencemar Udara DKI Jakarta" yang diperoleh dari kaggle. Dataset ini berisi informasi mengenai lokasi oengukuran kualitas udara, partikulat dan polutan pencemaran udara.
#
# Sumber dataset: https://www.kaggle.com/datasets/yunaperdana/indeks-standar-pencemaran-udara-spku-dkijakarta

# %% [markdown]
# ##  Struktur Data

# %% [markdown]
# Dataset ini memiliki 11 kolom dan 775 baris, dengan kolom utama antara lain:
# *  tanggal : Tanggal pengukuran kualitas udara
# * stasiun : Lokasi pengukuran di stasiun
# *  pm10 : Partikulat salah satu parameter yang diukur
#
# *  pm25 : Partikulat salah satu parameter yang diukur
#
# * so2 : Sulfida (dalam bentuk SO2) salah satu parameter yang diukur
#
# *   co : Carbon Monoksida salah satu parameter yand diukur
# *   o3 : Ozon salah satu parameter yang diukur
# *  no2 : NItrogen dioksida salah satu parameter yang diukur
# *   max : Nilai ukur paling tinggi dari seluruh parameter yang diukur dalam waktu yang sama
#
# * critical : Parameter yang hasil pengukurannya paling tinggi
#
# *  categori : Kategori hasil perhitungan indeks standar pencemaran udara

# %% [markdown]
# # Informasi Data

# %%
df
# Out:
#         tanggal                           stasiun  pm10  pm25   so2    co  \
# 0    2021-01-01               DKI4 (Lubang Buaya)  41.0   NaN  37.0  14.0
# 1    2021-01-01                DKI1 (Bunderan HI)  38.0  53.0  29.0   6.0
# 2    2021-01-02                DKI1 (Bunderan HI)  27.0  46.0  27.0   7.0
# 3    2021-01-03                DKI1 (Bunderan HI)  44.0  58.0  25.0   7.0
# 4    2021-01-04                DKI1 (Bunderan HI)  30.0  48.0  24.0   4.0
# ..          ...                               ...   ...   ...   ...   ...
# 770  2021-12-08  DKI5 (Kebon Jeruk) Jakarta Barat  44.0  66.0  17.0  13.0
# 771  2021-12-09  DKI5 (Kebon Jeruk) Jakarta Barat  30.0  50.0  20.0   5.0
# 772  2021-12-13  DKI5 (Kebon Jeruk) Jakarta Barat  22.0  45.0  20.0   3.0
# 773  2021-12-30  DKI5 (Kebon Jeruk) Jakarta Barat  53.0  75.0  25.0  15.0
# 774  2021-12-31  DKI5 (Kebon Jeruk) Jakarta Barat  60.0  87.0  28.0  19.0
#
#        o3   no2 max critical categori
# 0    35.0   4.0  41     PM10     BAIK
# 1    31.0  13.0  53     PM25   SEDANG
# 2    47.0   7.0  47       O3     BAIK
# 3    40.0  13.0  58     PM25   SEDANG
# 4    32.0   7.0  48     PM25     BAIK
# ..    ...   ...  ..      ...      ...
# 770  23.0  30.0  66     PM25   SEDANG
# 771  31.0  15.0  50     PM25     BAIK
# 772  16.0  14.0  45     PM25     BAIK
# 773  23.0  44.0  75     PM25   SEDANG
# 774  30.0  53.0  87     PM25   SEDANG
#
# [775 rows x 11 columns]

# %% [markdown]
# ## Memeriksa Struktur Data

# %%
print("Jumlah baris dan kolom:", df.shape)
# Out:
# Jumlah baris dan kolom: (775, 11)

# %%
print("\nTipe data setiap kolom:\n", df.dtypes)
# Out:
# Tipe data setiap kolom:
#  tanggal      object
# stasiun      object
# pm10        float64
# pm25        float64
# so2         float64
# co          float64
# o3          float64
# no2         float64
# max          object
# critical     object
# categori     object
# dtype: object

# %%
print("\nStatistik deskriptif:\n", df.describe())
# Out:
# Statistik deskriptif:
#               pm10        pm25         so2          co          o3         no2
# count  743.000000  732.000000  753.000000  762.000000  739.000000  760.000000
# mean    52.981157   82.870219   35.442231   11.599738   30.016238   19.213158
# std     18.407624   30.237380   12.628580    5.101199   13.773222    8.981863
# min     15.000000   20.000000    3.000000    2.000000    7.000000    4.000000
# 25%     37.000000   57.000000   26.000000    8.000000   20.000000   13.000000
# 50%     56.000000   86.000000   37.000000   11.000000   28.000000   18.000000
# 75%     66.000000  106.000000   43.000000   14.000000   36.000000   24.000000
# max    179.000000  174.000000   82.000000   44.000000  151.000000   63.000000

# %%
df.corr(numeric_only=True)
# Out:
#           pm10      pm25       so2        co        o3       no2
# pm10  1.000000  0.853117  0.498182  0.408741  0.307034  0.500113
# pm25  0.853117  1.000000  0.400782  0.375076  0.238479  0.483414
# so2   0.498182  0.400782  1.000000 -0.001521  0.365545  0.097520
# co    0.408741  0.375076 -0.001521  1.000000  0.038629  0.514404
# o3    0.307034  0.238479  0.365545  0.038629  1.000000  0.002475
# no2   0.500113  0.483414  0.097520  0.514404  0.002475  1.000000

# %% [markdown]
# # MISSING VALUES

# %% [markdown]
# ## Melihat Missing Values

# %%
print((df.isna().sum() / len(df)) *100)
# Out:
# tanggal     0.000000
# stasiun     0.000000
# pm10        4.129032
# pm25        5.548387
# so2         2.838710
# co          1.677419
# o3          4.645161
# no2         1.935484
# max         0.000000
# critical    0.000000
# categori    0.129032
# dtype: float64

# %% [markdown]
# Terdapat value kosong pada kolom 'pm10', 'pm25', 's02', 'co', 'o3', 'no2', 'categori' sehingga kita melakukan pengecekan nilai kosong pada masing-masing kolom.

# %% [markdown]
# Pengecekan nilai kosong pada kolom 'pm10'

# %%
df[df['pm10'].isnull()]
# Out:
#         tanggal                           stasiun  pm10   pm25   so2    co  \
# 32   2021-01-16  DKI5 (Kebon Jeruk) Jakarta Barat   NaN    NaN  18.0  12.0
# 33   2021-01-17  DKI5 (Kebon Jeruk) Jakarta Barat   NaN    NaN  20.0  15.0
# 34   2021-01-18  DKI5 (Kebon Jeruk) Jakarta Barat   NaN    NaN  22.0   8.0
# 123  2021-02-02  DKI5 (Kebon Jeruk) Jakarta Barat   NaN   55.0  28.0   9.0
# 126  2021-02-05  DKI5 (Kebon Jeruk) Jakarta Barat   NaN   48.0  28.0   8.0
# 127  2021-02-06  DKI5 (Kebon Jeruk) Jakarta Barat   NaN   34.0  21.0   4.0
# 128  2021-02-07  DKI5 (Kebon Jeruk) Jakarta Barat   NaN   29.0  22.0   5.0
# 129  2021-02-08  DKI5 (Kebon Jeruk) Jakarta Barat   NaN   41.0  23.0   6.0
# 130  2021-02-09  DKI5 (Kebon Jeruk) Jakarta Barat   NaN   57.0  31.0   9.0
# 170  2021-03-11  DKI5 (Kebon Jeruk) Jakarta Barat   NaN   41.0  20.0   5.0
# 184  2021-04-19              DKI2 (Kelapa Gading)   NaN  107.0  52.0   NaN
# 200  2021-04-12                  DKI3 (Jagakarsa)   NaN   69.0  27.0  15.0
# 370  2021-07-11              DKI2 (Kelapa Gading)   NaN    NaN  54.0  10.0
# 579  2021-09-21               DKI4 (Lubang Buaya)   NaN   99.0  44.0   9.0
# 580  2021-09-22               DKI4 (Lubang Buaya)   NaN  119.0  44.0  10.0
# 581  2021-09-23               DKI4 (Lubang Buaya)   NaN  116.0  43.0   9.0
# 582  2021-09-24               DKI4 (Lubang Buaya)   NaN  109.0  46.0   8.0
# 583  2021-09-25               DKI4 (Lubang Buaya)   NaN  102.0  45.0   7.0
# 584  2021-09-28               DKI4 (Lubang Buaya)   NaN   69.0  41.0   6.0
# 585  2021-09-29               DKI4 (Lubang Buaya)   NaN  102.0  45.0  13.0
# 586  2021-09-30               DKI4 (Lubang Buaya)   NaN  117.0  45.0  13.0
# 609  2021-10-01               DKI4 (Lubang Buaya)   NaN   91.0  45.0  10.0
# 610  2021-10-02               DKI4 (Lubang Buaya)   NaN  127.0  46.0  10.0
# 611  2021-10-03               DKI4 (Lubang Buaya)   NaN   96.0  44.0   9.0
# 612  2021-10-04               DKI4 (Lubang Buaya)   NaN  110.0  44.0  11.0
# 617  2021-10-13               DKI4 (Lubang Buaya)   NaN   91.0  44.0   8.0
# 618  2021-10-14               DKI4 (Lubang Buaya)   NaN  131.0  44.0  12.0
# 621  2021-10-17               DKI4 (Lubang Buaya)   NaN  126.0  39.0  13.0
# 624  2021-10-20               DKI4 (Lubang Buaya)   NaN   96.0  45.0  10.0
# 625  2021-10-21               DKI4 (Lubang Buaya)   NaN    NaN  44.0  10.0
# 635  2021-10-31               DKI4 (Lubang Buaya)   NaN   79.0   NaN   NaN
# 753  2021-12-18               DKI4 (Lubang Buaya)   NaN   69.0  42.0  13.0
#
#        o3   no2  max critical     categori
# 32   37.0   8.0   37       CO         BAIK
# 33   32.0   9.0   32       CO         BAIK
# 34   31.0   4.0   31       CO         BAIK
# 123  14.0  25.0   55     PM25       SEDANG
# 126  14.0  35.0   48     PM25         BAIK
# 127  24.0   6.0   34     PM25         BAIK
# 128  20.0   7.0   29     PM25         BAIK
# 129  17.0  11.0   41     PM25         BAIK
# 130  15.0  21.0   57     PM25       SEDANG
# 170  22.0   8.0   41     PM25         BAIK
# 184  41.0  22.0  107     PM25  TIDAK SEHAT
# 200   NaN  16.0   69     PM25       SEDANG
# 370  54.0  13.0   54      SO2       SEDANG
# 579  32.0  20.0   99     PM25       SEDANG
# 580  22.0  21.0  119     PM25  TIDAK SEHAT
# 581  24.0  18.0  116     PM25  TIDAK SEHAT
# 582  21.0  18.0  109     PM25  TIDAK SEHAT
# 583  26.0  16.0  102     PM25  TIDAK SEHAT
# 584  38.0  15.0   69     PM25       SEDANG
# 585  38.0  24.0  102     PM25  TIDAK SEHAT
# 586  40.0  27.0  117     PM25  TIDAK SEHAT
# 609  35.0  33.0   91     PM25       SEDANG
# 610  35.0  19.0  127     PM25  TIDAK SEHAT
# 611  32.0  19.0   96     PM25       SEDANG
# 612  33.0  24.0  110     PM25  TIDAK SEHAT
# 617  38.0  19.0   91     PM25       SEDANG
# 618  45.0  32.0  131     PM25  TIDAK SEHAT
# 621  53.0  27.0  126     PM25  TIDAK SEHAT
# 624  33.0  17.0   96     PM25       SEDANG
# 625  48.0  18.0   48       O3         BAIK
# 635   NaN   NaN   79     PM25       SEDANG
# 753  24.0  17.0   69     PM25       SEDANG

# %% [markdown]
# Melakukan pengecekan nilai kosong pada kolom 'pm25'

# %%
df[df['pm25'].isnull()]
# Out:
#         tanggal                           stasiun  pm10  pm25   so2    co  \
# 0    2021-01-01               DKI4 (Lubang Buaya)  41.0   NaN  37.0  14.0
# 20   2021-01-04  DKI5 (Kebon Jeruk) Jakarta Barat  27.0   NaN  14.0   7.0
# 21   2021-01-05  DKI5 (Kebon Jeruk) Jakarta Barat  41.0   NaN  15.0   9.0
# 22   2021-01-06  DKI5 (Kebon Jeruk) Jakarta Barat  33.0   NaN  12.0  19.0
# 23   2021-01-07  DKI5 (Kebon Jeruk) Jakarta Barat  27.0   NaN  13.0  11.0
# 24   2021-01-08  DKI5 (Kebon Jeruk) Jakarta Barat  36.0   NaN  18.0  19.0
# 25   2021-01-09  DKI5 (Kebon Jeruk) Jakarta Barat  46.0   NaN  17.0  26.0
# 675  2021-11-29              DKI2 (Kelapa Gading)  22.0   NaN   4.0   8.0
# 676  2021-11-30              DKI2 (Kelapa Gading)  30.0   NaN   5.0   8.0
# 737  2021-12-01              DKI2 (Kelapa Gading)  53.0   NaN   8.0  12.0
# 740  2021-12-29              DKI2 (Kelapa Gading)  28.0   NaN  32.0  12.0
# 744  2021-12-14                  DKI3 (Jagakarsa)  40.0   NaN  44.0   7.0
#
#        o3   no2 max critical categori
# 0    35.0   4.0  41     PM10     BAIK
# 20   31.0   4.0  31       CO     BAIK
# 21   28.0   NaN  41     PM10     BAIK
# 22   46.0   NaN  46       CO     BAIK
# 23   36.0   NaN  36       CO     BAIK
# 24   28.0   NaN  36     PM10     BAIK
# 25   27.0  12.0  46     PM10     BAIK
# 26   34.0   5.0  34       CO     BAIK
# 27   34.0   9.0  34       CO     BAIK
# 28   38.0   6.0  38       CO     BAIK
# 29   27.0   9.0  27       CO     BAIK
# 30   36.0   7.0  36       CO     BAIK
# 31   41.0   7.0  52     PM10   SEDANG
# 32   37.0   8.0  37       CO     BAIK
# 33   32.0   9.0  32       CO     BAIK
# 34   31.0   4.0  31       CO     BAIK
# 35   35.0   5.0  35       CO     BAIK
# 36   33.0   NaN  33       CO     BAIK
# 37   37.0   8.0  43     PM10     BAIK
# 38   40.0  15.0  45     PM10     BAIK
# 39   44.0  22.0  80     PM10   SEDANG
# 40   29.0   NaN  29       CO     BAIK
# 41   67.0  13.0  67       CO   SEDANG
# 42   36.0  16.0  57     PM10   SEDANG
# 43   20.0   NaN  20       CO     BAIK
# 44   28.0   NaN  28     PM10     BAIK
# 45   32.0  11.0  32       CO     BAIK
# 46   27.0  10.0  27       CO     BAIK
# 47   29.0   8.0  41     PM10     BAIK
# 252  52.0   NaN  52     PM10   SEDANG
# 370  54.0  13.0  54      SO2   SEDANG
# 371  44.0  13.0  64     PM10   SEDANG
# 382  59.0  20.0  61     PM10   SEDANG
# 399  14.0  11.0  50     PM10     BAIK
# 558  32.0  13.0  49      SO2     BAIK
# 625  48.0  18.0  48       O3     BAIK
# 673  45.0  15.0  45       O3     BAIK
# 674  47.0   9.0  47       O3     BAIK
# 675  42.0  12.0  42       O3     BAIK
# 676  44.0  17.0  44       O3     BAIK
# 737  41.0  30.0  53     PM10   SEDANG
# 740  37.0  29.0  37       O3     BAIK
# 744  37.0  11.0  44      SO2     BAIK

# %% [markdown]
# Melakukan pengecekan nilai kosong pada kolom 'so2'
#
# ---

# %%
df[df['so2'].isnull()]
# Out:
#         tanggal                           stasiun  pm10   pm25  so2    co  \
# 309  2021-06-11               DKI4 (Lubang Buaya)  64.0   99.0  NaN   9.0
# 542  2021-09-26              DKI2 (Kelapa Gading)  56.0   74.0  NaN   7.0
# 543  2021-09-27              DKI2 (Kelapa Gading)  53.0   77.0  NaN  11.0
# 544  2021-09-28              DKI2 (Kelapa Gading)  49.0   71.0  NaN   8.0
# 590  2021-09-13  DKI5 (Kebon Jeruk) Jakarta Barat  51.0   70.0  NaN   6.0
# 591  2021-09-14  DKI5 (Kebon Jeruk) Jakarta Barat  26.0   37.0  NaN   3.0
# 635     PM25       SEDANG
# 684     PM25       SEDANG
# 685     PM25         BAIK
# 739     PM25       SEDANG
# 745     PM25       SEDANG
# 746     PM25       SEDANG
# 747     PM25       SEDANG
# 755     PM25       SEDANG
# 756     PM25       SEDANG
# 757     PM25       SEDANG
# 758     PM25  TIDAK SEHAT
# 759     PM25       SEDANG
# 760     PM25       SEDANG
# 761     PM25  TIDAK SEHAT
# 762     PM25       SEDANG

# %% [markdown]
# Melakukan pengecekan nilai kosong pada kolom 'no2'

# %%
df[df['no2'].isnull()]
# Out:
#         tanggal                           stasiun  pm10  pm25   so2    co  \
# 21   2021-01-05  DKI5 (Kebon Jeruk) Jakarta Barat  41.0   NaN  15.0   9.0
# 22   2021-01-06  DKI5 (Kebon Jeruk) Jakarta Barat  33.0   NaN  12.0  19.0
# 23   2021-01-07  DKI5 (Kebon Jeruk) Jakarta Barat  27.0   NaN  13.0  11.0
# 24   2021-01-08  DKI5 (Kebon Jeruk) Jakarta Barat  36.0   NaN  18.0  19.0
# 36   2021-01-20  DKI5 (Kebon Jeruk) Jakarta Barat  30.0   NaN  15.0   7.0
# 40   2021-01-24  DKI5 (Kebon Jeruk) Jakarta Barat  27.0   NaN  14.0   9.0
# 43   2021-01-27  DKI5 (Kebon Jeruk) Jakarta Barat  15.0   NaN  16.0   5.0
# 44   2021-01-28  DKI5 (Kebon Jeruk) Jakarta Barat  28.0   NaN  19.0  11.0
# 250  2021-05-14              DKI2 (Kelapa Gading)  56.0  70.0  51.0   9.0
# 251  2021-05-15              DKI2 (Kelapa Gading)  54.0  67.0  54.0  10.0
# 252  2021-05-16              DKI2 (Kelapa Gading)  52.0   NaN  50.0   9.0
# 608  2021-10-31                  DKI3 (Jagakarsa)  45.0  27.0   NaN  28.0
# 635  2021-10-31               DKI4 (Lubang Buaya)   NaN  79.0   NaN   NaN
# 755  2021-12-24               DKI4 (Lubang Buaya)  34.0  65.0   NaN   NaN
# 756  2021-12-25               DKI4 (Lubang Buaya)  56.0  85.0  15.0  23.0
#
#        o3  no2 max critical categori
# 21   28.0  NaN  41     PM10     BAIK
# 22   46.0  NaN  46       CO     BAIK
# 23   36.0  NaN  36       CO     BAIK
# 24   28.0  NaN  36     PM10     BAIK
# 36   33.0  NaN  33       CO     BAIK
# 40   29.0  NaN  29       CO     BAIK
# 43   20.0  NaN  20       CO     BAIK
# 44   28.0  NaN  28     PM10     BAIK
# 250  52.0  NaN  70     PM25   SEDANG
# 251  40.0  NaN  67     PM25   SEDANG
# 252  52.0  NaN  52     PM10   SEDANG
# 608  39.0  NaN  45     PM10     BAIK
# 635   NaN  NaN  79     PM25   SEDANG
# 755   NaN  NaN  65     PM25   SEDANG
# 756   NaN  NaN  85     PM25   SEDANG

# %% [markdown]
# Melakukan pengecekan nilai kosong pada kolom 'categori'

# %%
df[df['categori'].isnull()]
# Out:
#         tanggal             stasiun  pm10  pm25  so2    co   o3   no2   max  \
# 723  2021-12-03  DKI1 (Bunderan HI)  49.0  31.0  9.0  19.0  7.0  49.0  PM25
#
#     critical categori
# 723     BAIK      NaN

# %% [markdown]
# ## Mengatasi Missing Values

# %%
df['pm10'] = df['pm10'].fillna(df['pm10'].dropna().mean())
df['pm25'] = df['pm25'].fillna(df['pm25'].dropna().mean())
df['so2'] = df['so2'].fillna(df['so2'].dropna().mean())
df['co'] = df['co'].fillna(df['co'].dropna().mean())
df['o3'] = df['o3'].fillna(df['o3'].dropna().mean())
df['no2'] = df['no2'].fillna(df['no2'].dropna().mean())

# %%
print(df[['pm10', 'pm25', 'so2', 'co', 'o3', 'no2']].isnull().sum())
# Out:
# pm10    0
# pm25    0
# so2     0
# co      0
# o3      0
# no2     0
# dtype: int64

# %% [markdown]
# # DUPLICATED VALUES

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tanggal, stasiun, pm10, pm25, so2, co, o3, no2, max, critical, categori]
# Index: []

# %% [markdown]
# nilai dalam duplicated values tidak muncul yang artinya tidak ada nilai duplikat di dalam dataset.

# %% [markdown]
# # OUTLIERS

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom  Persentase Outliers
# pm10              0.129032
# pm25              0.000000
# so2               0.516129
# co                2.451613
# o3                3.483871
# no2               2.838710

# %%
columns_to_impute = ['pm10','pm25', 'so2', 'co', 'o3', 'no2']

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom  Persentase Outliers
# pm10                   0.0
# pm25                   0.0
# so2                    0.0
# co                     0.0
# o3                     0.0
# no2                    0.0

# %% [markdown]
# # INCONSISTENT VALUES

# %%
df
# Out:
#         tanggal                           stasiun  pm10       pm25   so2  \
# 0    2021-01-01               DKI4 (Lubang Buaya)  41.0  82.870219  37.0
# 1    2021-01-01                DKI1 (Bunderan HI)  38.0  53.000000  29.0
# 2    2021-01-02                DKI1 (Bunderan HI)  27.0  46.000000  27.0
# 3    2021-01-03                DKI1 (Bunderan HI)  44.0  58.000000  25.0
# 4    2021-01-04                DKI1 (Bunderan HI)  30.0  48.000000  24.0
# ..          ...                               ...   ...        ...   ...
# 770  2021-12-08  DKI5 (Kebon Jeruk) Jakarta Barat  44.0  66.000000  17.0
# 771  2021-12-09  DKI5 (Kebon Jeruk) Jakarta Barat  30.0  50.000000  20.0
# 772  2021-12-13  DKI5 (Kebon Jeruk) Jakarta Barat  22.0  45.000000  20.0
# 773  2021-12-30  DKI5 (Kebon Jeruk) Jakarta Barat  53.0  75.000000  25.0
# 774  2021-12-31  DKI5 (Kebon Jeruk) Jakarta Barat  60.0  87.000000  28.0
#
#        co    o3   no2 max critical categori
# 0    14.0  35.0   4.0  41     PM10     BAIK
# 1     6.0  31.0  13.0  53     PM25   SEDANG
# 2     7.0  47.0   7.0  47       O3     BAIK
# 3     7.0  40.0  13.0  58     PM25   SEDANG
# 4     4.0  32.0   7.0  48     PM25     BAIK
# ..    ...   ...   ...  ..      ...      ...
# 770  13.0  23.0  30.0  66     PM25   SEDANG
# 771   5.0  31.0  15.0  50     PM25     BAIK
# 772   3.0  16.0  14.0  45     PM25     BAIK
# 773  15.0  23.0  40.5  75     PM25   SEDANG
# 774  19.0  30.0  40.5  87     PM25   SEDANG
#
# [775 rows x 11 columns]

# %%
inconsistent_values = df[df['pm10'] < 0]
print(f'Jumlah nilai tidak konsisten: {len(inconsistent_values)}')
# Out:
# Jumlah nilai tidak konsisten: 0

# %% [markdown]
# # CONSTRUCT DATA

# %% [markdown]
# Menambahkan kolom baru di dalam dataset. Membuat 3 kolom baru dalam dataset antara lain:
#
#
# *   kategorikan_kualitas_udara
# *   rata_rata_kualitas_udara
# *   nama hari

# %%
def kategorikan_kualitas_udara(pm10):
    if pm10 <= 50:
        return 'Baik'
    elif pm10 <= 100:
        return 'Sedang'
    elif pm10 <= 150:
        return 'Tidak Sehat untuk Kelompok Sensitif'
    elif pm10 <= 200:
        return 'Tidak Sehat'
    else:
        return 'Sangat Tidak Sehat'

df['kategori_kualitas_udara'] = df['pm10'].apply(kategorikan_kualitas_udara)

# %%
df['rata_rata_kualitas_udara'] = df[['pm10', 'pm25', 'so2', 'co', 'o3', 'no2']].mean(axis=1)

# %%
df['tanggal'] = pd.to_datetime(df['tanggal'])
df['hari'] = df['tanggal'].dt.day_name()

# %%
df
# Out:
#        tanggal                           stasiun  pm10       pm25   so2    co  \
# 0   2021-01-01               DKI4 (Lubang Buaya)  41.0  82.870219  37.0  14.0
# 1   2021-01-01                DKI1 (Bunderan HI)  38.0  53.000000  29.0   6.0
# 2   2021-01-02                DKI1 (Bunderan HI)  27.0  46.000000  27.0   7.0
# 3   2021-01-03                DKI1 (Bunderan HI)  44.0  58.000000  25.0   7.0
# 4   2021-01-04                DKI1 (Bunderan HI)  30.0  48.000000  24.0   4.0
# ..         ...                               ...   ...        ...   ...   ...
# 770 2021-12-08  DKI5 (Kebon Jeruk) Jakarta Barat  44.0  66.000000  17.0  13.0
# 771 2021-12-09  DKI5 (Kebon Jeruk) Jakarta Barat  30.0  50.000000  20.0   5.0
# 772 2021-12-13  DKI5 (Kebon Jeruk) Jakarta Barat  22.0  45.000000  20.0   3.0
# 773 2021-12-30  DKI5 (Kebon Jeruk) Jakarta Barat  53.0  75.000000  25.0  15.0
# 774 2021-12-31  DKI5 (Kebon Jeruk) Jakarta Barat  60.0  87.000000  28.0  19.0
#
#        o3   no2 max critical categori kategori_kualitas_udara  \
# 0    35.0   4.0  41     PM10     BAIK                    Baik
# 1    31.0  13.0  53     PM25   SEDANG                    Baik
# 2    47.0   7.0  47       O3     BAIK                    Baik
# 3    40.0  13.0  58     PM25   SEDANG                    Baik
# 4    32.0   7.0  48     PM25     BAIK                    Baik
# ..    ...   ...  ..      ...      ...                     ...
# 770  23.0  30.0  66     PM25   SEDANG                    Baik
# 771  31.0  15.0  50     PM25     BAIK                    Baik
# 772  16.0  14.0  45     PM25     BAIK                    Baik
# 773  23.0  40.5  75     PM25   SEDANG                  Sedang
# 774  30.0  40.5  87     PM25   SEDANG                  Sedang
#
#      rata_rata_kualitas_udara       hari
# 0                   35.645036     Friday
# 1                   28.333333     Friday
# 2                   26.833333   Saturday
# 3                   31.166667     Sunday
# 4                   24.166667     Monday
# ..                        ...        ...
# 770                 32.166667  Wednesday
# 771                 25.166667   Thursday
# 772                 20.000000     Monday
# 773                 38.583333   Thursday
# 774                 44.083333     Friday
#
# [775 rows x 14 columns]

# %% [markdown]
# # Data Reduction

# %% [markdown]
# Menghapus kolom yang tidak relevan dengan dataset.

# %%
df = df.drop(["kategori_kualitas_udara", "rata_rata_kualitas_udara"], axis=1)

# %%
df
# Out:
#        tanggal                           stasiun  pm10       pm25   so2    co  \
# 0   2021-01-01               DKI4 (Lubang Buaya)  41.0  82.870219  37.0  14.0
# 1   2021-01-01                DKI1 (Bunderan HI)  38.0  53.000000  29.0   6.0
# 2   2021-01-02                DKI1 (Bunderan HI)  27.0  46.000000  27.0   7.0
# 3   2021-01-03                DKI1 (Bunderan HI)  44.0  58.000000  25.0   7.0
# 4   2021-01-04                DKI1 (Bunderan HI)  30.0  48.000000  24.0   4.0
# ..         ...                               ...   ...        ...   ...   ...
# 770 2021-12-08  DKI5 (Kebon Jeruk) Jakarta Barat  44.0  66.000000  17.0  13.0
# 771 2021-12-09  DKI5 (Kebon Jeruk) Jakarta Barat  30.0  50.000000  20.0   5.0
# 772 2021-12-13  DKI5 (Kebon Jeruk) Jakarta Barat  22.0  45.000000  20.0   3.0
# 773 2021-12-30  DKI5 (Kebon Jeruk) Jakarta Barat  53.0  75.000000  25.0  15.0
# 774 2021-12-31  DKI5 (Kebon Jeruk) Jakarta Barat  60.0  87.000000  28.0  19.0
#
#        o3   no2 max critical categori       hari
# 0    35.0   4.0  41     PM10     BAIK     Friday
# 1    31.0  13.0  53     PM25   SEDANG     Friday
# 2    47.0   7.0  47       O3     BAIK   Saturday
# 3    40.0  13.0  58     PM25   SEDANG     Sunday
# 4    32.0   7.0  48     PM25     BAIK     Monday
# ..    ...   ...  ..      ...      ...        ...
# 770  23.0  30.0  66     PM25   SEDANG  Wednesday
# 771  31.0  15.0  50     PM25     BAIK   Thursday
# 772  16.0  14.0  45     PM25     BAIK     Monday
# 773  23.0  40.5  75     PM25   SEDANG   Thursday
# 774  30.0  40.5  87     PM25   SEDANG     Friday
#
# [775 rows x 12 columns]
